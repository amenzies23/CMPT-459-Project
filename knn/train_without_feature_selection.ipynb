# %%
import random
import numpy as np

from core.preprocessing import load_and_preprocess_data
from core.outlier_detection import remove_outliers
from core.classification import (
    classify_with_knn,
)
from core.visualization import (
    visualize_ground_truth,
    visualize_knn_decision_boundary,
)

from utils import divider

# Set random seeds
seed = 42
random.seed(seed)
np.random.seed(seed)

divider("1: Load & Preprocess Data")
X_raw, X_scaled, y, label_encoder, scaler = load_and_preprocess_data(
    "../data/plant_health_data.csv"
)

divider("2: Outlier Detection (LOF)")
X_clean, y_clean = remove_outliers(X_scaled, y)

divider("3: Ground Truth Visualization")
visualize_ground_truth(X_clean, y_clean, label_encoder)

divider("4: KNN Decision Boundary Visualization")
visualize_knn_decision_boundary(X_clean, y_clean, n_neighbors=5)

print("Running KNN with hyperparameter tuning...")
classify_with_knn(
    X_clean, y_clean, label_encoder
)
# Out:
# ================================================================================
# 1: Load & Preprocess Data
# ================================================================================
#
# ================================================================================
# 2: Outlier Detection (LOF)
# ================================================================================
# [Outlier Detection] Removed 12 outliers.
#
# ================================================================================
# 3: Ground Truth Visualization
# ================================================================================
# ================================================================================
# 4: KNN Decision Boundary Visualization
# ================================================================================
# Running KNN with hyperparameter tuning...
# [Classification] Best Params: {'n_neighbors': 12, 'weights': 'uniform'}
# [Classification Report]
#                  precision    recall  f1-score   support
#
#         Healthy       0.68      0.61      0.64        59
#     High Stress       0.77      0.80      0.79        99
# Moderate Stress       0.53      0.55      0.54        80
#
#        accuracy                           0.67       238
#       macro avg       0.66      0.65      0.66       238
#    weighted avg       0.67      0.67      0.67       238
# Fold scores: 0.6978051980285785
# Mean: 0.6978051980285785 Std: 0.0
# [Cross-validation Accuracy]: 0.6978
# KNeighborsClassifier(n_neighbors=12)
